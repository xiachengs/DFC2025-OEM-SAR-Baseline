# %%
# !git clone https://github.com/xiachengs/DFC2025-OEM-SAR-Baseline.git
# Out:
# Cloning into 'DFC2025-OEM-SAR-Baseline'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 182 (delta 56), reused 52 (delta 34), pack-reused 96 (from 1)
# Receiving objects: 100% (182/182), 75.09 MiB | 6.81 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
# !pip install rasterio
# !pip install segmentation_models_pytorch
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.12.14)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 65.9 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl.metadata (32 kB)
# Collecting efficientnet-pytorch>=0.6.1 (from segmentation_models_pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.27.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (1.26.4)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (11.0.0)
# Collecting pretrainedmodels>=0.7.1 (from segmentation_models_pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (1.17.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (1.0.12)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.12.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.3->segmentation_models_pytorch) (2.4.1)
# Collecting munch (from pretrainedmodels>=0.7.1->segmentation_models_pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm>=0.9->segmentation_models_pytorch) (0.4.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.3->segmentation_models_pytorch) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.3->segmentation_models_pytorch) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2024.12.14)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.3->segmentation_models_pytorch) (2024.2.0)
# Downloading segmentation_models_pytorch-0.4.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 7.1 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16424 sha256=2f779559c922fb6ad2964c7106d97703c665ec8f928618218ce754fc17a8a394
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60944 sha256=9664b6756e50e5659f9a706d2c11275ab9598865376057d2f2fc98014f0342a0
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, pretrainedmodels, segmentation_models_pytorch
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation_models_pytorch-0.4.0

# %%
# !cp /kaggle/input/mit-b0/mit_b0.pth /kaggle/working/DFC2025-OEM-SAR-Baseline/pretrained

# %%
cd /kaggle/working/DFC2025-OEM-SAR-Baseline
# Out:
# /kaggle/working/DFC2025-OEM-SAR-Baseline

# %%
# !python train.py --data_root '/kaggle/input/dfc25-track1-trainval/train/labels'\
                 --phi 'b0'
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.1 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Loading pretrained weight: 'pretrained/mit_b0.pth' done.
#
# Successful Load Key: ['backbone.patch_embed1.proj.bias', 'backbone.patch_embed1.norm.weight', 'backbone.patch_embed1.norm.bias', 'backbone.patch_embed2.proj.weight', 'backbone.patch_embed2.proj.bias', 'backbone.patch_embed2.norm.weight', 'backbone.patch_embed2.norm.bias', 'backbone.patch_embed3.proj.weight', 'backbone.patch_embed3.proj.bias', 'backbone.patch_embed3.norm.weight', 'backbone.patch_embed3.norm.bias', 'backbone.patch_embed4.proj.weight', 'backbone.patch_embed4.proj.bias', 'backbone.patch_embed4.norm.weig ……
# Successful Load Key Num: 175
#
# Fail To Load Key: ['backbone.patch_embed1.proj.weight', 'backbone.head.weight', 'backbone.head.bias'] ……
# Fail To Load Key num: 3
# Number of parameters:  4889865
# Number of GPUs : 2
# Number of epochs   : 50
# Number of classes  : 9
# Batch size         : 8
# Device             : cuda
# Total samples      : 4333
# Training samples   : 3899
# Validation samples : 434
#
# Epoch: 1
# Train: 100%|█████████| 488/488 [04:39<00:00,  1.75it/s, CELoss=1.68, mIoU=0.132]
# Valid: 100%|████████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.5, mIoU=0.176]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 2
# Train: 100%|█████████| 488/488 [04:32<00:00,  1.79it/s, CELoss=1.49, mIoU=0.191]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.34, mIoU=0.214]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 3
# Train: 100%|█████████| 488/488 [04:32<00:00,  1.79it/s, CELoss=1.42, mIoU=0.213]
# Valid: 100%|████████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.35, mIoU=0.21]
#
# Epoch: 4
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.37, mIoU=0.232]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.32, mIoU=0.235]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 5
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.36, mIoU=0.232]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.29, mIoU=0.237]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 6
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.33, mIoU=0.241]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.28, mIoU=0.241]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 7
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.29, mIoU=0.257]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.26, mIoU=0.261]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 8
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.28, mIoU=0.263]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.25, mIoU=0.254]
#
# Epoch: 9
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.27, mIoU=0.268]
# Valid: 100%|████████████| 55/55 [01:07<00:00,  1.22s/it, CELoss=1.2, mIoU=0.276]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 10
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.25, mIoU=0.273]
# Valid: 100%|████████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.2, mIoU=0.263]
#
# Epoch: 11
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.23, mIoU=0.278]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.17, mIoU=0.277]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 12
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.21, mIoU=0.288]
# Valid: 100%|█████████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.2, mIoU=0.27]
#
# Epoch: 13
# Train: 100%|█████████| 488/488 [04:32<00:00,  1.79it/s, CELoss=1.21, mIoU=0.291]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.13, mIoU=0.298]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 14
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.19, mIoU=0.294]
# Valid: 100%|███████████| 55/55 [01:06<00:00,  1.21s/it, CELoss=1.14, mIoU=0.293]
#
# Epoch: 15
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.18, mIoU=0.297]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.24s/it, CELoss=1.12, mIoU=0.295]
#
# Epoch: 16
# Train: 100%|█████████| 488/488 [04:32<00:00,  1.79it/s, CELoss=1.19, mIoU=0.294]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.12, mIoU=0.301]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 17
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.17, mIoU=0.302]
# Valid: 100%|████████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.1, mIoU=0.304]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 18
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.14, mIoU=0.309]
# Valid: 100%|████████████| 55/55 [01:07<00:00,  1.22s/it, CELoss=1.1, mIoU=0.306]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 19
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.17, mIoU=0.303]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.12, mIoU=0.298]
#
# Epoch: 20
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.14, mIoU=0.31]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.22s/it, CELoss=1.12, mIoU=0.282]
#
# Epoch: 21
# Train: 100%|█████████| 488/488 [04:32<00:00,  1.79it/s, CELoss=1.14, mIoU=0.314]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.11, mIoU=0.305]
#
# Epoch: 22
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.13, mIoU=0.309]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.08, mIoU=0.315]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 23
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.11, mIoU=0.319]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.08, mIoU=0.319]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 24
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.11, mIoU=0.317]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.24s/it, CELoss=1.12, mIoU=0.296]
#
# Epoch: 25
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.1, mIoU=0.321]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.08, mIoU=0.317]
#
# Epoch: 26
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.09, mIoU=0.32]
# Valid: 100%|████████████| 55/55 [01:07<00:00,  1.22s/it, CELoss=1.13, mIoU=0.31]
#
# Epoch: 27
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.1, mIoU=0.327]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.12, mIoU=0.289]
#
# Epoch: 28
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.08, mIoU=0.325]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.06, mIoU=0.316]
#
# Epoch: 29
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.09, mIoU=0.325]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.07, mIoU=0.321]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 30
# Train: 100%|██████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.1, mIoU=0.323]
# Valid: 100%|████████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.14, mIoU=0.31]
#
# Epoch: 31
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.09, mIoU=0.328]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.05, mIoU=0.322]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 32
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.07, mIoU=0.331]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.08, mIoU=0.315]
#
# Epoch: 33
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.05, mIoU=0.337]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.05, mIoU=0.322]
#
# Epoch: 34
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.06, mIoU=0.334]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.24s/it, CELoss=1.03, mIoU=0.326]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 35
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.05, mIoU=0.333]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.07, mIoU=0.325]
#
# Epoch: 36
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.05, mIoU=0.339]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.04, mIoU=0.326]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 37
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.04, mIoU=0.339]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.03, mIoU=0.326]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 38
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.04, mIoU=0.337]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.07, mIoU=0.317]
#
# Epoch: 39
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.79it/s, CELoss=1.04, mIoU=0.346]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.02, mIoU=0.326]
#
# Epoch: 40
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.03, mIoU=0.341]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.06, mIoU=0.324]
#
# Epoch: 41
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.03, mIoU=0.344]
# Valid: 100%|███████████| 55/55 [01:09<00:00,  1.26s/it, CELoss=1.05, mIoU=0.317]
#
# Epoch: 42
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.02, mIoU=0.345]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.04, mIoU=0.328]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 43
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.03, mIoU=0.346]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.24s/it, CELoss=1.03, mIoU=0.333]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 44
# Train: 100%|█████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=1.02, mIoU=0.348]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.03, mIoU=0.335]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 45
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.0, mIoU=0.351]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.04, mIoU=0.326]
#
# Epoch: 46
# Train: 100%|████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=0.999, mIoU=0.354]
# Valid: 100%|███████████| 55/55 [01:07<00:00,  1.23s/it, CELoss=1.02, mIoU=0.333]
#
# Epoch: 47
# Train: 100%|██████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.0, mIoU=0.355]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.02, mIoU=0.335]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 48
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.01, mIoU=0.357]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.24s/it, CELoss=1.03, mIoU=0.331]
#
# Epoch: 49
# Train: 100%|████████| 488/488 [04:34<00:00,  1.78it/s, CELoss=0.994, mIoU=0.354]
# Valid: 100%|███████████| 55/55 [01:08<00:00,  1.25s/it, CELoss=1.02, mIoU=0.337]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
#
# Epoch: 50
# Train: 100%|█████████| 488/488 [04:33<00:00,  1.78it/s, CELoss=1.02, mIoU=0.349]
# Valid: 100%|████████████| 55/55 [01:09<00:00,  1.26s/it, CELoss=1.0, mIoU=0.338]
# Model saved in the folder :  weight
# Model name is :  SAR_Pesudo_DataParallel_s0_CELoss
# Processing time: 17103.454660654068

# %%
# !cd /kaggle/working/DFC2025-OEM-SAR-Baseline
# !git pull https://github.com/xiachengs/DFC2025-OEM-SAR-Baseline.git
# Out:
# From https://github.com/xiachengs/DFC2025-OEM-SAR-Baseline
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.
